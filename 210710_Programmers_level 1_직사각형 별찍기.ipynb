# %% [markdown]
# #programmers_level 1_직사각형 별찍기
# ### 정수 n과 m이 주어질 때, '*'을 가로(n) x 세로(m) 직사각형 형태를 출력

# %%
n, m = map(int, input().strip().split(' '))
print((n*'*'+'\n')*m)
# Out:
# 5 3
# *****
# *****
# *****
