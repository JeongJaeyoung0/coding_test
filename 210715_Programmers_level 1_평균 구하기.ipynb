# %% [markdown]
# #programmers_level 1_평균 구하기
# ### 정수 배열 arr의 평균값을 반환

# %%
def solution(arr):
    return sum(arr)/len(arr)

# %%
solution([1,2,3,4])
# Out:
# 2.5

# %%
solution([5, 5])
# Out:
# 5.0
